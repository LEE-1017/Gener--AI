# %% [markdown]
# <a href="https://colab.research.google.com/github/LEE-1017/Gener--AI/blob/main/HW3_NTNU_%E6%95%B8%E5%AD%B8114_41040123s_%E6%9D%8E%E6%B5%A9%E6%8F%9A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![317.png](data:image/png;base64,...)

# %% [markdown]
# 這是我生成的結果，不過沒有輸出，網址是:https://www.thiswaifudoesnotexist.net/
#
# 然後基於GAN為什麼被取代我的想法如下因為GAN需要大量的原始圖片，而且生成原理算是依樣畫葫蘆，所以時不時會有極度"扭曲"的結果，並且因為所有的結果依賴於資料，比起擴散模型，這方法在AI作圖時靈活性較低，往往一個模型只能服務一個主題
